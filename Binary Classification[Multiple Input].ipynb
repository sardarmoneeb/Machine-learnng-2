# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_excel(r"D:\Kaggle datasets\placement.xlsx")

# %%
dataset.head(5)
# Out:
#    cgpa  placement_exam_marks  placed
# 0  7.19                    26       1
# 1  7.46                    38       1
# 2  7.54                    40       1
# 3  6.42                     8       1
# 4  7.23                    17       0

# %%
dataset.shape
# Out:
# (1000, 3)

# %%
dataset.isnull().sum()
# Out:
# cgpa                    0
# placement_exam_marks    0
# placed                  0
# dtype: int64

# %%
x = dataset.iloc[:,:-1]
y = dataset["placed"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=40)

# %%
x_train.shape
# Out:
# (800, 2)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression(random_state=40)
lr.fit(x_train,y_train)
# Out:
# LogisticRegression(random_state=40)

# %%
# from sklearn.linear_model import LogisticRegression
# # lr = LogisticRegression(class_weight='balanced')
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# x = scaler.fit_transform(x)

# %%
lr.score(x_test,y_test)*100
# Out:
# 56.00000000000001

# %%
lr.predict([[7.19,26]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
sns.scatterplot(x="cgpa",y="placement_exam_marks",data=dataset,hue = "placed")
plt.show()

# %%
# from mlxtend.plotting import plot_decision_regions
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x,y.to_numpy(),clf=lr)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
# import pandas as pd
# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import StandardScaler
# from sklearn.linear_model import LogisticRegression
# from sklearn.metrics import accuracy_score, classification_report

# # Step 1: Load the dataset
# # file_path = 'placement.xlsx'  # Replace with your file path
# # df = pd.read_excel(file_path)
# dataset = pd.read_excel(r"D:\Kaggle datasets\placement.xlsx")

# # Extract features (first two columns) and target (last column)
# X = dataset.iloc[:, :2]  # First two columns as features
# y = dataset.iloc[:, -1]  # Last column as target

# # Step 2: Preprocess the data
# # Feature scaling
# scaler = StandardScaler()
# X_scaled = scaler.fit_transform(X)

# # Split the data into training and testing sets
# X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# # Step 3: Train Logistic Regression
# model = LogisticRegression(random_state=42)  # Set random_state for consistency
# model.fit(X_train, y_train)

# # Step 4: Evaluate the model
# y_pred = model.predict(X_test)

# # Print evaluation metrics
# print("Accuracy:", accuracy_score(y_test, y_pred))
# print("\nClassification Report:\n", classification_report(y_test, y_pred))
