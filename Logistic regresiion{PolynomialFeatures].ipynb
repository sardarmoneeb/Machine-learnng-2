# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_excel(r"D:\placement.xlsx")

# %%
dataset.head(5)
# Out:
#    cgpa  placement_exam_marks  placed
# 0  7.19                    26       1
# 1  7.46                    38       1
# 2  7.54                    40       1
# 3  6.42                     8       1
# 4  7.23                    17       0

# %%
dataset.shape
# Out:
# (299, 3)

# %%
dataset.isnull().sum()
# Out:
# cgpa                    0
# placement_exam_marks    0
# placed                  0
# dtype: int64

# %%
x = dataset.iloc[:,:-1]
y = dataset["placed"]

# %%
y.shape
# Out:
# (299,)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape
# Out:
# (239, 2)

# %%
y_train.shape
# Out:
# (239,)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 46.666666666666664

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=lr)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # Polynomial Features

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset  = dataset = pd.read_excel(r"D:\placement.xlsx")

# %%
dataset.head(5)
# Out:
#    cgpa  placement_exam_marks  placed
# 0  7.19                    26       1
# 1  7.46                    38       1
# 2  7.54                    40       1
# 3  6.42                     8       1
# 4  7.23                    17       0

# %%
x= dataset.iloc[:,:-1]
y = dataset["placed"]

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pf=PolynomialFeatures(degree=2)
pf.fit(x)
x = pd.DataFrame(pf.transform(x))

# %%
x
# Out:
#        0     1     2        3       4       5
# 0    1.0  7.19  26.0  51.6961  186.94   676.0
# 1    1.0  7.46  38.0  55.6516  283.48  1444.0
# 2    1.0  7.54  40.0  56.8516  301.60  1600.0
# 3    1.0  6.42   8.0  41.2164   51.36    64.0
# 4    1.0  7.23  17.0  52.2729  122.91   289.0
# ..   ...   ...   ...      ...     ...     ...
# 294  1.0  6.12  17.0  37.4544  104.04   289.0
# 295  1.0  6.02  64.0  36.2404  385.28  4096.0
# 296  1.0  6.99  19.0  48.8601  132.81   361.0
# 297  1.0  7.03  32.0  49.4209  224.96  1024.0
# 298  1.0  6.16  48.0  37.9456  295.68  2304.0
#
# [299 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 46.666666666666664
