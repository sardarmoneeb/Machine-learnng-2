# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from mlxtend.plotting import plot_decision_regions

# %%
dataset = pd.read_excel(r"D:\balanced_placement.xlsx")

# %%
dataset.head(5)
# Out:
#    cgpa  score  placed
# 0  8.15      9       0
# 1  6.40     35       0
# 2  7.76     59       0
# 3  6.48     33       0
# 4  7.28     15       0

# %%
dataset.isnull().sum()
# Out:
# cgpa      0
# score     0
# placed    0
# dtype: int64

# %%
dataset["placed"].value_counts()
# Out:
# placed
# 0    146
# 1    146
# Name: count, dtype: int64

# %%
x = dataset.iloc[:,:-1]
y = dataset["placed"]

# %%
# sns.kdeplot(data = dataset["cgpa"])
# sns.kdeplot(data = dataset["score"])
# sns.kdeplot(data = dataset["placed"])
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 54.23728813559322

# %%
from sklearn.naive_bayes import GaussianNB,BernoulliNB,MultinomialNB

# %%
gnb = GaussianNB()
gnb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
gnb.score(x_test,y_test)*100 , gnb.score(x_train,y_train)*100
# Out:
# (54.23728813559322, 54.506437768240346)

# %%
bnb = BernoulliNB()
bnb.fit(x_train,y_train)
# Out:
# BernoulliNB()

# %%
bnb.score(x_test,y_test)*100 , bnb.score(x_train,y_train)*100
# Out:
# (49.152542372881356, 50.21459227467812)

# %%
mnb = MultinomialNB()
mnb.fit(x_train,y_train)
# Out:
# MultinomialNB()

# %%
mnb.score(x_test,y_test)*100 , mnb.score(x_train,y_train)*100
# Out:
# (55.932203389830505, 55.36480686695279)
